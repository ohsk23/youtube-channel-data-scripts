# %%
pip install requests
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from config import API_KEY

BASE_URL = "https://www.googleapis.com/youtube/v3"

# %%
def get_videos_by_search(channel_id, max_results=50, page_token=None):
    url = f"{BASE_URL}/search"
    print(API_KEY)
    params = {
        "key": API_KEY,
        "channelId": channel_id,
        "part": "snippet",
        "order": "date",
        "maxResults": max_results,
    }
    if page_token:
        params["pageToken"] = page_token
    response = requests.get(url, params=params)
    return response.json()

# %%
from utils import save_data, load_data, get_videos

def fetch_all_videos(channel_id, page_token = None):
    # 기존 데이터 불러오기
    existing_videos = load_data("data/videos/videos.json") or []
    
    # 새로운 데이터 가져오기
    response = get_videos(channel_id, 10, page_token)
    print(response)
    new_videos = response.get("items", [])
    
    # 기존 데이터에 새로운 데이터 추가
    all_videos = existing_videos + new_videos
    
    # 모든 비디오를 합치고 publishedAt 기준으로 정렬
    all_videos = existing_videos + new_videos
    all_videos.sort(key=lambda x: x['snippet']['publishedAt'], reverse=True)  # 최신순 정렬

    # 전체 데이터 저장
    save_data(all_videos, "data/videos/videos.json")
    
    print(f"기존 비디오: {len(existing_videos)}개")
    print(f"새로 추가된 비디오: {len(new_videos)}개")
    print(f"전체 비디오: {len(all_videos)}개")
    print(f"Next Page Token: {response.get('nextPageToken')}")
    return response.get('nextPageToken')

# %%
channel_id = 'UCXIJgqnII2ZOINSWNOGFThA'

# %%
def fetch_all_videos_loop(channel_id, start_page_token = None):
    next_token = start_page_token
    while True:
        next_token = fetch_all_videos(channel_id, next_token)
        print(next_token)
        if not next_token:
            # 더 이상 가져올 페이지가 없다면 종료
            break

    print("모든 영상을 성공적으로 가져왔습니다!")

# %%
fetch_all_videos_loop(channel_id, "CCEQAA")
# Out:
# AIzaSyCOXptgIO1AmsMiBAXEzgqvN_ynUREMSnU
# ...
